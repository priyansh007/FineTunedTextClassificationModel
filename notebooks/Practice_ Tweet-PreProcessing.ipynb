# %%
# !pip install contractions
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 10.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd # Pandas is for working with tables
from imblearn.over_sampling import RandomOverSampler #Over sampling
import plotly.graph_objects as go #Graph
from sklearn.preprocessing import LabelEncoder #Converts category to numerical
from imblearn.under_sampling import RandomUnderSampler #Under sampling
import re
import contractions
from google.colab import drive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-00456fe11dc9> in <cell line: 7>()
#       5 from imblearn.under_sampling import RandomUnderSampler #Under sampling
#       6 import re
# ----> 7 import contractions
#       8 from google.colab import drive
#       9 from google.colab import drive
#
# ModuleNotFoundError: No module named 'contractions'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !wget -O dataset.csv "https://drive.google.com/uc?export=download&id=15yCLNdNtGfONwugxtrFTmqHk_ZMvkve0&confirm=NEW_FILE_CONFIRM_CODE"
# Out:
# --2023-07-10 21:31:33--  https://drive.google.com/uc?export=download&id=15yCLNdNtGfONwugxtrFTmqHk_ZMvkve0&confirm=NEW_FILE_CONFIRM_CODE
# Resolving drive.google.com (drive.google.com)... 74.125.20.113, 74.125.20.139, 74.125.20.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.20.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-c8-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/si4ekh1rhuohsehcqqdugkaf061qi7rs/1689024675000/12434615743218103933/*/15yCLNdNtGfONwugxtrFTmqHk_ZMvkve0?e=download&uuid=032a7157-465c-40a4-a72b-cf5cab1a0fb8 [following]
# ...
# --2023-07-10 21:31:35--  https://doc-0c-c8-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/si4ekh1rhuohsehcqqdugkaf061qi7rs/1689024675000/12434615743218103933/*/15yCLNdNtGfONwugxtrFTmqHk_ZMvkve0?e=download&uuid=032a7157-465c-40a4-a72b-cf5cab1a0fb8
# ...

# %% [markdown]
# # Load CSV

# %%
dataframe = pd.read_csv('/content/dataset.csv')

dataframe[0:10]
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...
# 5  1956968477       worry  Re-pinging @ghostridah14: why didn't you go to...
# 6  1956968487     sadness  I should be sleep, but im not! thinking about ...
# 7  1956968636       worry               Hmmm. http://www.djhero.com/ is down
# 8  1956969035     sadness            @charviray Charlene my love. I miss you
# 9  1956969172     sadness         @kelcouch I'm sorry  at least it's Friday?

# %%
dataframe.iloc[1,0] #[Row,Column]
# Out:
# 1956967666

# %%
dataframe.drop('tweet_id', axis=1, inplace=True)

sentiment = dataframe.pop('sentiment')
dataframe['sentiment'] = sentiment
dataframe.head()
# Out:
#                                              content   sentiment
# 0  @tiffanylue i know  i was listenin to bad habi...       empty
# 1  Layin n bed with a headache  ughhhh...waitin o...     sadness
# 2                Funeral ceremony...gloomy friday...     sadness
# 3               wants to hang out with friends SOON!  enthusiasm
# 4  @dannycastillo We want to trade with someone w...     neutral

# %%
dataframe.dropna(inplace=True)

# %% [markdown]
# # Plot graph of sentiment values

# %%
def create_bar_graph(x_list,y_list):
  # Create a bar graph using Plotly
  fig = go.Figure(data=go.Bar(x=x_list , y=y_list))

  # Customize the graph layout
  fig.update_layout(
      title="Data instances of different sentiments",
      xaxis_title="Sentiments",
      yaxis_title="Value count",
      width=800,  # Set the width of the graph
      height=500  # Set the height of the graph
  )
  return fig

# %%
dataframe['sentiment'].value_counts()
# Out:
# neutral       8638
# worry         8459
# happiness     5209
# sadness       5165
# love          3842
# surprise      2187
# fun           1776
# relief        1526
# hate          1323
# empty          827
# enthusiasm     759
# boredom        179
# anger          110
# Name: sentiment, dtype: int64

# %%
vc = dataframe['sentiment'].value_counts()
category = list(vc.index)

# %%
graph = create_bar_graph(category, vc)
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Reduce Categories

# %%
df_reduce = dataframe.copy()

df_reduce['sentiment'] = df_reduce['sentiment'].replace(['happiness', 'enthusiasm', 'surprise'], 'fun')
df_reduce['sentiment'] = df_reduce['sentiment'].replace('boredom', 'sadness')
#To-Do task: Replace 'anger' category with 'hate' category.
#and Combine 'relief' and 'empty' into 'neutral' category
df_reduce['sentiment'] = df_reduce['sentiment'].replace('anger', 'hate')
df_reduce['sentiment'] = df_reduce['sentiment'].replace(['relief', 'empty'], 'neutral')

# %%
vc = df_reduce['sentiment'].value_counts()
graph = create_bar_graph(list(vc.index),vc)
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Label encoding

# %%
# Create an instance of LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the data
encoded_data = label_encoder.fit_transform(df_reduce['sentiment'])
df_reduce['sentiment'] = encoded_data

# %% [markdown]
# 'fun', 'hate', 'love', 'neutral', 'sadness', 'worry' - 1,2,4,0,3,5,6
#
# fun-1
# hate-2

# %%
df_reduce.head()
# Out:
#                                              content  sentiment
# 0  @tiffanylue i know  i was listenin to bad habi...          3
# 1  Layin n bed with a headache  ughhhh...waitin o...          4
# 2                Funeral ceremony...gloomy friday...          4
# 3               wants to hang out with friends SOON!          0
# 4  @dannycastillo We want to trade with someone w...          3

# %%
label_encoder.classes_
#To-Do: Write down Category name and their index in next text box. E.g. Anger - 0 ...
# Out:
# array(['fun', 'hate', 'love', 'neutral', 'sadness', 'worry'], dtype=object)

# %% [markdown]
# Fun - 0, Hate - 1, Love - 2, 'neutral' - 3, 'sadness' - 4, 'worry' - 5

# %%
vc = df_reduce['sentiment'].value_counts()
graph = create_bar_graph(list(vc.index),vc)
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
X_values = df_reduce[['content']]
y_values = df_reduce['sentiment']

# %%
y_values
# Out:
# 0        3
# 1        4
# 2        4
# 3        0
# 4        3
#         ..
# 39995    3
# 39996    2
# 39997    2
# 39998    0
# 39999    2
# Name: sentiment, Length: 40000, dtype: int64

# %% [markdown]
# # Oversampling

# %%
oversampler = RandomOverSampler(random_state=42)
x_over_sample, y_over_sample = oversampler.fit_resample(X_values, y_values)

# %%
vc = y_over_sample.value_counts()
graph = create_bar_graph(list(vc.index),vc)
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Under sampling

# %%
undersampler = RandomUnderSampler(random_state=42)
x_under_sample, y_under_sample = undersampler.fit_resample(X_values, y_values)

# %%
vc = y_under_sample.value_counts()
graph = create_bar_graph(list(vc.index),vc)
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Utilize under and over sampling

# %%
class_counts = y_values.value_counts()
average_count = class_counts.mean()
average_count = int(average_count)

# %%
#To-Do: Utilize undersampling and oversampling both.
#Goal: if len of category is more than average - Do under sampling.
#If len of category is more than average - Do over sampling
#Utilize the sampling_strategy
oversampler = RandomOverSampler(random_state=42, sampling_strategy={1: average_count,
                                                                    2: average_count,
                                                                    4: average_count})
x_over_sample, y_over_sample = oversampler.fit_resample(X_values, y_values)

# %%
vc = y_over_sample.value_counts()
graph = create_bar_graph(list(vc.index),vc)
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
undersampler = RandomUnderSampler(random_state=42, sampling_strategy={0: average_count,
                                                                    3: average_count,
                                                                    5: average_count})
x_balanced, y_balanced  = undersampler.fit_resample(x_over_sample, y_over_sample)

# %%
vc = y_balanced.value_counts()
graph = create_bar_graph(list(vc.index),vc)
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x_balanced.head()
# Out:
#                                              content
# 0    @7thscreen Damn! First Yes, than Frank Zappa...
# 1  What a fantastic full-on weekend!  Going to fi...
# 2  Trying to stay awake  Anyone have any tips how...
# 3                     I beat 3 bosses in Castelvania
# 4  @nikkiwoods no problem! i think it's a great t...

# %% [markdown]
# # Clean text data

# %%
import nltk
import urllib
import bs4 as bs
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import string
from gensim.models import Word2Vec

nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
def remove_stopwords(sentences):
    stop_words = set(stopwords.words('english'))
    filtered_sentences = []

    for sentence in sentences:
      words = word_tokenize(sentence)
      temp = [word for word in words if word not in stop_words]
      filtered_sent = ' '.join(temp)
      filtered_sentences.append(filtered_sent)

    return filtered_sentences

def remove_punctuation(sentences):
    punctuation = string.punctuation
    filtered_sentences = []

    for sentence in sentences:
      temp = [char for char in sentence if char not in punctuation]
      new_sent = ''.join(temp)
      filtered_sentences.append(new_sent)
    return filtered_sentences

def stem_sentences(sentences):
    stemmer = PorterStemmer()
    stemmed_sentences = []

    for sentence in sentences:
        words = word_tokenize(sentence)
        temp = [stemmer.stem(word) for word in words]
        stemmed_sent = ' '.join(temp)
        stemmed_sentences.append(stemmed_sent)
    return stemmed_sentences

def lem_sentences(sentences):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentences = []

    for sentence in sentences:
        words = word_tokenize(sentence)
        temp = [lemmatizer.lemmatize(word) for word in words]
        stemmed_sent = ' '.join(temp)
        lemmatized_sentences.append(stemmed_sent)

    return lemmatized_sentences
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def preprocess_sentence(sentences):
    # Remove punctuation
    sentences = remove_punctuation(sentences)
    sentences = remove_stopwords(sentences)
    sentences = stem_sentences(sentences)
    sentences = lem_sentences(sentences)
    # WRITE YOUR CODE HERE #
    return sentences

# %%
def clean_content(text):

  # remove twitter handles
  clean_text = re.sub(r'@\w+\s?', "", str(text))

  # convert to lowercase
  clean_text = clean_text.lower()

  # remove links http:// or https://
  clean_text = re.sub(r'https?:\/\/\S+', '', clean_text)

  # remove links beginning with www. and ending with .com
  clean_text = re.sub(r'www\.[a-z]?\.?(com)+|[a-z]+\.(com)', '', clean_text)

  # remove html reference characters
  clean_text = re.sub(r'&[a-z]+;', '', clean_text)

  # remove non-letter characters besides spaces "/", ";" "[", "]" "=", "#" Regex syntax
  clean_text = re.sub(r"[^a-z\s\(\-:\)\\\/\];='#]", '', clean_text)

  clean_text = contractions.fix(clean_text)
  sentences = sent_tokenize(clean_text)
  filtered_sentences = preprocess_sentence(sentences)
  clean_text = '.'.join(filtered_sentences)
  return clean_text

# %%
max_len = x_balanced.shape[0]
for i in range(max_len):
  x_balanced.iloc[i,0] = clean_content(x_balanced.iloc[i,0])

# %%
x_balanced
# Out:
#                                                  content
# 0                              damn first ye frank zappa
# 1      fantast fullon weekend go finish high cheeki c...
# 2                      tri stay awak anyon tip keep awak
# 3                                   beat bos castelvania
# 4                      problem think great thing reflect
# ...                                                  ...
# 39991  mayst success luca first polic contact neighbo...
# 39992  miss closest freindshirley went franc summer m...
# 39993         sent download link spanish crylet know get
# 39994                          tire headach like sunshin
# 39995                                 awwwwwwi know feel
#
# [39996 rows x 1 columns]

# %%
combined_df = pd.concat([x_balanced, y_balanced], axis=1)

# %%
combined_df.dropna(inplace=True)

# %%
combined_df
# Out:
#                                                  content  sentiment
# 0                              damn first ye frank zappa          0
# 1      fantast fullon weekend go finish high cheeki c...          0
# 2                      tri stay awak anyon tip keep awak          0
# 3                                   beat bos castelvania          0
# 4                      problem think great thing reflect          0
# ...                                                  ...        ...
# 39991  mayst success luca first polic contact neighbo...          5
# 39992  miss closest freindshirley went franc summer m...          5
# 39993         sent download link spanish crylet know get          5
# 39994                          tire headach like sunshin          5
# 39995                                 awwwwwwi know feel          5
#
# [39996 rows x 2 columns]

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/TweetData/new_dataset.csv'

combined_df.to_csv(file_path, index=False)
